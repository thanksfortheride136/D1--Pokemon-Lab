# %% [markdown]
# ### Welcome
# This is a very basic overview of the PANDAS Python Library. DataFrame- An object that is a table with rows and columns, created using pandas from an CSV file exported from excel, google sheets etc. THe first 3 are setup steps that you need to do all the time.

# %% [markdown]
# ### 1. Imports Pandas Library
# pd allows us to shorten bits of code

# %%
import pandas as pd

# %% [markdown]
# ### 2. Set how many rows you want to display in the notebook.
# We are limiting it to 100 rows in this example.

# %%
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ### 3. Read the CSV File
# Read the csv file an asssign it to an easy to use variable name (Must be uploaded into Jupyter Lab

# %%
pokemon = pd.read_csv("pokemon.csv")

# %% [markdown]
# ### 4. Display the Data
# All you need to do is type the name of the variable you created for the data set.

# %%
pokemon
# Out:
#                       name     type subtype  total  hp  attack  defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      special_attack  special_defense  speed  generation  legendary
# ...

# %% [markdown]
# ---
# ### Acessing Specific Columns
# You can access specific columns using variable name (using dot notation) followed by the name of the column, ie. `pokemon.type` as seen below. These wont be sorted.

# %%
pokemon.type
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: type, Length: 800, dtype: object

# %% [markdown]
# ---
# ### Descriptive Methods
# Below will contain several Pandas Descriptive Methods that are useful for sorting / categorizing / Analyzing Data.

# %% [markdown]
# ### value_counts()
# Tells you how many of each data is in a column. Use: `series.column_name.value_counts()`. In the example below the count of all the different types are shown from the "type" column, there are 112 pokemon with the "Water" type.

# %%
pokemon.type.value_counts()
# Out:
# type
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %% [markdown]
# ### mean()
# Gets the mean of an entire column. Use: `series.column.mean()`. Access multiple columns using: `series[["column_name1", "column_name2", "column_name3"]].mean()`
#
# -You can also compute the mean of a a Boolean Column (uses true or false instead of a number), True will map to 1 and False to 0. Therefore the % tells you what percent is true. Use: `series.column.mean() * 100`

# %%
pokemon.hp.mean()
# Out:
# 69.25875

# %%
pokemon[["hp", "attack", "defense"]]
# Out:
#      hp  attack  defense
# 0    45      49       49
# 1    60      62       63
# 2    80      82       83
# 3    80     100      123
# 4    39      52       43
# ..   ..     ...      ...
# 795  50     100      150
# 796  50     160      110
# 797  80     110       60
# 798  80     160       60
# 799  80     110      120
#
# [800 rows x 3 columns]

# %%
pokemon.legendary.mean()*100
# Out:
# 8.125

# %% [markdown]
# ### sort_values()
# Allows for sorting of data. Use: `series.sort_values("column you want to sort by")`

# %%
pokemon.sort_values("hp")
# Out:
#           name     type subtype  total   hp  attack  defense  special_attack  \
# 316   Shedinja      Bug   Ghost    236    1      90       45              30
# 55     Diglett   Ground     NaN    265   10      55       25              35
# 381     Feebas    Water     NaN    200   20      15       20              10
# 139   Magikarp    Water     NaN    200   20      10       55              15
# 388    Duskull    Ghost     NaN    295   20      40       90              30
# ..         ...      ...     ...    ...  ...     ...      ...             ...
# 655  Alomomola    Water     NaN    470  165      75       80              40
# 351    Wailord    Water     NaN    500  170      90       45              90
# 217  Wobbuffet  Psychic     NaN    405  190      33       58              33
# 121    Chansey   Normal     NaN    450  250       5        5              35
# 261    Blissey   Normal     NaN    540  255      10       10              75
#
# ...

# %% [markdown]
# ___
# ### Filtering Methods
# Filtering out columns gives great flexibility in how we use data. Below are some common uses.

# %% [markdown]
# ### Filtering a Boolean Column
# To filter a Boolean column you should first create a variable that contains: `variable = series[series.column]. Simply call the variable, since they are a boolean value, it will sort to show you the "True" values by default. Note that it also shows ALL columns that correspond to the "True" in the legendary column.

# %%
legendary = pokemon[pokemon.legendary]
legendary
# Out:
#                          name      type   subtype  total   hp  attack  \
# 156                  Articuno       Ice    Flying    580   90      85
# 157                    Zapdos  Electric    Flying    580   90      90
# 158                   Moltres      Fire    Flying    580   90     100
# 162                    Mewtwo   Psychic       NaN    680  106     110
# 163       MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 164       MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# 262                    Raikou  Electric       NaN    580   90      85
# 263                     Entei      Fire       NaN    580  115     115
# 264                   Suicune     Water       NaN    580  100      75
# 269                     Lugia   Psychic    Flying    680  106      90
# 270                     Ho-oh      Fire    Flying    680  106     130
# 414                  Regirock      Rock       NaN    580   80     100
# ...

# %% [markdown]
# ### Filtering by column data
# If you want to filter by content inside a column you will need to utilize a variable to hold the information and use a relational operator "==". You can also use others.
# Use: `variable = series[series.column == "keyword"]`. Call the variable name to show. Use relational operators to display combinations of filtered data. See the 2nd example for use of relational operators to filter by several keywords in data.

# %%
ice_pokemon = pokemon[pokemon.type == "Ice"]
ice_pokemon
# Out:
#                   name type  subtype  total   hp  attack  defense  \
# 133               Jynx  Ice  Psychic    455   65      50       35
# 156           Articuno  Ice   Flying    580   90      85      100
# 238             Swinub  Ice   Ground    250   50      50       40
# 239          Piloswine  Ice   Ground    450  100     100       80
# 243           Delibird  Ice   Flying    330   45      55       45
# 257           Smoochum  Ice  Psychic    305   45      30       15
# 395            Snorunt  Ice      NaN    300   50      50       50
# 396             Glalie  Ice      NaN    480   80      80       80
# 397  GlalieMega Glalie  Ice      NaN    580   80     120       80
# 398             Spheal  Ice    Water    290   70      40       50
# 399             Sealeo  Ice    Water    410   90      60       70
# 400            Walrein  Ice    Water    530  110      80       90
# 415             Regice  Ice      NaN    580   80      50      100
# ...

# %%
#Displays only gen1 fire pokemon
fire_gen1 = pokemon[(pokemon.generation == 1) & (pokemon.type == "Fire")] 
fire_gen1
# Out:
#                           name  type subtype  total  hp  attack  defense  \
# 4                   Charmander  Fire     NaN    309  39      52       43
# 5                   Charmeleon  Fire     NaN    405  58      64       58
# 6                    Charizard  Fire  Flying    534  78      84       78
# 7    CharizardMega Charizard X  Fire  Dragon    634  78     130      111
# 8    CharizardMega Charizard Y  Fire  Flying    634  78     104       78
# 42                      Vulpix  Fire     NaN    299  38      41       40
# 43                   Ninetales  Fire     NaN    505  73      76       75
# 63                   Growlithe  Fire     NaN    350  55      70       45
# 64                    Arcanine  Fire     NaN    555  90     110       80
# 83                      Ponyta  Fire     NaN    410  50      85       55
# 84                    Rapidash  Fire     NaN    500  65     100       70
# 135                     Magmar  Fire     NaN    495  65      95       57
# ...

# %%
#Displays pokemon with a special attack greater than 70 and a speed greater than a 70 and a defense less than 90.
spAttack_speed_defense = pokemon[(pokemon.special_attack > 70) & (pokemon.speed > 70) & (pokemon.defense < 90)]
spAttack_speed_defense
# Out:
#                           name      type subtype  total  hp  attack  defense  \
# 2                     Venusaur     Grass  Poison    525  80      82       83
# 5                   Charmeleon      Fire     NaN    405  58      64       58
# 6                    Charizard      Fire  Flying    534  78      84       78
# 8    CharizardMega Charizard Y      Fire  Flying    634  78     104       78
# 23         PidgeotMega Pidgeot    Normal  Flying    579  83      80       80
# ..                         ...       ...     ...    ...  ..     ...      ...
# 771                   Hawlucha  Fighting  Flying    500  78      92       75
# 772                    Dedenne  Electric   Fairy    431  67      58       57
# 776                     Goodra    Dragon     NaN    600  90     100       70
# 791                    Noivern    Flying  Dragon    535  85      70       80
# 798         HoopaHoopa Unbound   Psychic    Dark    680  80     160       60
#
# ...

# %% [markdown]
# ___
# ### Grouping
# Grouping allows you to group data frames together for powerful comparison abilities.

# %% [markdown]
# ### groupby()
# Allows you to group columns together. Use: `series.groupby("column").[other methods]`
#
# 1. In the first example below we are taking the mean speeds and grouping them by the type of pokemon. The mean speed of Bug pokemon is 61.6.
#
# 2. In the second example we are grouping and sorting by amount the mean amount of legendary pokemon in each generation. Generation 3 has the most legendary pokemon. Note that this can of course be saved in a variable.
#
# 3. In the third example we are grouping by the type again, but then we are finding the mean values of several columns and sorting the values by the amount of HP. Notice we need mean() for any values to be displayed.
#
# 4. In the final example we are grouping by generation, then seeing attack, special attack and defense. We are grouping by defense.

# %%
pokemon.groupby("type").speed.mean()
# Out:
# type
# Bug          61.681159
# Dark         76.161290
# Dragon       83.031250
# Electric     84.500000
# Fairy        48.588235
# Fighting     66.074074
# Fire         74.442308
# Flying      102.500000
# Ghost        64.343750
# Grass        61.928571
# Ground       63.906250
# Ice          63.458333
# Normal       71.551020
# Poison       63.571429
# Psychic      81.491228
# Rock         55.909091
# Steel        55.259259
# Water        65.964286
# Name: speed, dtype: float64

# %%
legendary_count_generation = pokemon.groupby("generation").legendary.mean().sort_values() * 100
legendary_count_generation
# Out:
# generation
# 1     3.614458
# 2     4.716981
# 5     9.090909
# 6     9.756098
# 4    10.743802
# 3    11.250000
# Name: legendary, dtype: float64

# %%
ptypes = pokemon.groupby("type")[["hp", "attack", "defense"]].mean().sort_values("hp")
ptypes
# Out:
#                  hp      attack     defense
# type
# Bug       56.884058   70.971014   70.724638
# Electric  59.795455   69.090909   66.295455
# Ghost     64.437500   73.781250   81.187500
# Steel     65.222222   92.703704  126.370370
# Rock      65.363636   92.863636  100.795455
# Dark      66.806452   88.387097   70.225806
# Poison    67.250000   74.678571   68.821429
# Grass     67.271429   73.214286   70.800000
# Fighting  69.851852   96.777778   65.925926
# Fire      69.903846   84.769231   67.769231
# Psychic   70.631579   71.456140   67.684211
# Flying    70.750000   78.750000   66.250000
# Ice       72.000000   72.750000   71.416667
# Water     72.062500   74.151786   72.946429
# Ground    73.781250   95.750000   84.843750
# Fairy     74.117647   61.529412   65.705882
# Normal    77.275510   73.469388   59.846939
# Dragon    83.312500  112.125000   86.375000

# %%
gen_attackpower_defense = pokemon.groupby("generation")[["attack", "special_attack", "defense"]].mean().sort_values("defense")
gen_attackpower_defense
# Out:
#                attack  special_attack    defense
# generation
# 1           76.638554       71.819277  70.861446
# 5           82.066667       71.987879  72.327273
# 2           72.028302       65.943396  73.386792
# 3           81.625000       75.806250  74.100000
# 6           75.804878       74.292683  76.682927
# 4           82.867769       76.404959  78.132231

# %% [markdown]
# ___
# ### More Complex Grouping (Grouping Multiple objects together)
# Grouping allows you to group data together with multiple columns as well.
# 1. This is showing how you would see the mean of legenday type pokemon, broken down by each type and subtype. We grouped type and subtype to get all the possible combinations, sorted by legendary mean. We also are display values that are greater than 0.
#
# 2. The second example is grouping by generation and type, displaying hp, attack and defense. Its being sorted by attack power.
#
# 3. In the third example we are doing the same thing as 2, however we are using `sort_values(by=["generation", "attack", "defense"]` to sort first by generation, then sort the individual values within attack / defense.

# %%
legendary_percentages = pokemon.groupby(["type", "subtype"]).legendary.mean().sort_values() 
legendary_percentages[legendary_percentages > 0]
# Out:
# type      subtype
# Steel     Psychic     0.142857
# Psychic   Flying      0.166667
# Grass     Flying      0.200000
# Dragon    Ground      0.200000
# Dark      Flying      0.200000
# Grass     Fighting    0.333333
# Dragon    Flying      0.333333
# Fire      Flying      0.333333
# Psychic   Fighting    0.333333
# Ground    Flying      0.500000
# Ice       Flying      0.500000
# Water     Dragon      0.500000
# Electric  Flying      0.600000
# Rock      Fairy       0.666667
# Psychic   Ghost       1.000000
# Ground    Fire        1.000000
# Ghost     Dragon      1.000000
# Fire      Water       1.000000
#           Steel       1.000000
# Psychic   Dark        1.000000
#           Fire        1.000000
# Steel     Dragon      1.000000
# Rock      Fighting    1.000000
# Dragon    Psychic     1.000000
#           Ice         1.000000
#           Fire        1.000000
# Steel     Fighting    1.000000
# Dragon    Electric    1.000000
# Name: legendary, dtype: float64

# %%
attack_defense_power_over_gens = pokemon.groupby(["type", "generation"])[["attack", "defense"]].mean().sort_values("generation")
attack_defense_power_over_gens
# Out:
#                          attack     defense
# type     generation
# Bug      1            76.428571   60.357143
# Dragon   1            94.000000   68.333333
# Electric 1            62.000000   64.666667
# Fairy    1            57.500000   60.500000
# Psychic  1            79.181818   63.181818
# Fire     1            88.642857   67.142857
# Poison   1            74.428571   67.000000
# Rock     1            87.500000  107.500000
# Fighting 1           102.857143   61.000000
# Ghost    1            53.750000   53.750000
# Normal   1            70.625000   56.583333
# Ground   1            81.875000   86.250000
# Water    1            74.193548   83.193548
# Grass    1            72.923077   73.692308
# Ice      1            67.500000   67.500000
# Steel    2            96.666667  190.000000
# Normal   2            63.133333   54.000000
# Fire     2            76.250000   68.875000
# Ice      2            58.750000   45.000000
# Poison   2            90.000000   80.000000
# ...

# %%
attack_defense_power_over_gens = (pokemon.groupby(["type", "generation"])[["attack", "defense"]].mean().sort_values(by=["generation", "attack", "defense"]))
attack_defense_power_over_gens
# Out:
#                          attack     defense
# type     generation
# Ghost    1            53.750000   53.750000
# Fairy    1            57.500000   60.500000
# Electric 1            62.000000   64.666667
# Ice      1            67.500000   67.500000
# Normal   1            70.625000   56.583333
# Grass    1            72.923077   73.692308
# Water    1            74.193548   83.193548
# Poison   1            74.428571   67.000000
# Bug      1            76.428571   60.357143
# Psychic  1            79.181818   63.181818
# Ground   1            81.875000   86.250000
# Rock     1            87.500000  107.500000
# Fire     1            88.642857   67.142857
# Dragon   1            94.000000   68.333333
# Fighting 1           102.857143   61.000000
# Fairy    2            57.000000   60.600000
# Grass    2            57.000000   65.000000
# Ice      2            58.750000   45.000000
# Ghost    2            60.000000   60.000000
# Normal   2            63.133333   54.000000
# ...

# %% [markdown]
# ___
# ### Plotting
# Pandas has good plotting capabilities, but using the seaborn library `pip3 install seaborn` has much better capabilities.
#
# Use: `import seaborn as sns`
#
# Set the default theme: `sns.set_theme()`

# %%
import seaborn as sns
sns.set_theme()

# %% [markdown]
# ### Histograms
# Good to visualize distribution of a series, puts data inot bins and plots the number of data points in each bin.
#
# Use: `sns.histplot(data=series, xaxis_value, yaxis_value)`

# %%
#plots a simple graph that counts each genrations pokemon
sns.histplot(data=pokemon, x="generation")
# Out:
# <Axes: xlabel='generation', ylabel='Count'>

# %%
#using the bins argument to increase / decrease bins
sns.histplot(data=pokemon, y="attack", bins=5)
# Out:
# <Axes: xlabel='Count', ylabel='attack'>

# %% [markdown]
# ### Barplot
# Good when you want to compare the distribution of a numeric variable across categories, choose one numerica column and one categorical column
#
# Use: `sns.barplot(data=series, xaxis_value, yaxis_value, errorbar="sd"[optional])`

# %%
sns.barplot(data=pokemon, x="special_attack", y="type", errorbar=None, palette="muted")
# Out:
# <Axes: xlabel='special_attack', ylabel='type'>

# %%
sns.barplot(data=pokemon, x="attack", y="type", errorbar=None)
# Out:
# <Axes: xlabel='attack', ylabel='type'>

# %% [markdown]
# ### Scatterplot
# Good to show a relationship between 2 numeric variables. Looking at a point in the example below gives you the y value or speed of a pokemon, tracing it down to the x value or attack gives the attack. Together 1 point will display those 2 values.
#
# Use: `sns.scatterplot(data=series, xvalue, yvalue)`
#
# In the 2nd we are distuingishing categories within the scatter plot using hue. You would want something with a small amount of options. In the pokemon data set I used generation for this, it has 6 options which may be a lot.
#
# Use: `sns.scatterplot(data=series, x="column_name", y="column_name", hue="column_name", alpha=int, s=int)`

# %%
sns.scatterplot(data=pokemon, x="attack", y="speed")
# Out:
# <Axes: xlabel='attack', ylabel='speed'>

# %%
sns.scatterplot(data=pokemon, x="defense", y="special_attack", hue="generation", alpha=0.5, s=60)
# Out:
# <Axes: xlabel='defense', ylabel='special_attack'>

# %% [markdown]
# ### relplot()
# Lets you plot across multiple categories and make several plots at once.
#
# You use an x and y parameter as usual, but there also is a `col` paraemeter which allows you to add different columns of charts. In the first example we are plotting the attack and speed variables, we are using `col="legendary"` to see how legendary vs non legendary pokemon's attack and speed values relate.
#
# Use: `sns.relplot(data=series, x="xvalue", y="yvalue", col="another_column")`
#
# In the 2nd example we are accessing values inside a column, instead of a full column.

# %%
sns.relplot(data=pokemon, x="speed", y="attack", col="legendary")
# Out:
# /home/cooperl/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fav_types = pokemon[pokemon.type.isin(["Fighting", "Ghost", "Grass"])]
sns.relplot(data=fav_types, x="hp", y="speed", hue="legendary", col="type", s=100)
# Out:
# /home/cooperl/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
